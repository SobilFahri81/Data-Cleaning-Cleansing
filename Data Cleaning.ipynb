# %%
import pandas as pd
import numpy as np
import re

# %%
data_hotel = pd.read_csv('7282_1.csv')
data_hotel.head(5)
# Out:
#    index                 address categories      city country   latitude  \
# 0      0  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611
# 1      1  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611
# 2      2  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611
# 3      3  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611
# 4      4  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611
#
#    longitude                name postalCode province          reviews.date  \
# 0  12.376187  Hotel Russo Palace      30126       GA  2013-09-22T00:00:00Z
# 1  12.376187  Hotel Russo Palace      30126       GA  2015-04-03T00:00:00Z
# 2  12.376187  Hotel Russo Palace      30126       GA  2014-05-13T00:00:00Z
# 3  12.376187  Hotel Russo Palace      30126       GA  2013-10-27T00:00:00Z
# 4  12.376187  Hotel Russo Palace      30126       GA  2015-03-05T00:00:00Z
#
#       reviews.dateAdded  reviews.doRecommend  reviews.id  reviews.rating  \
# ...

# %%
data_hotel.sample(5)
# Out:
#        index               address    categories          city country  \
# 785      785           375 Main St  Hotels,Hotel    Waterville      US
# 649      649           375 Main St  Hotels,Hotel    Waterville      US
# 34887  34887       1705 S State St        Hotels    Big Rapids      US
# 19847  19847      5500 28th St S E        Hotels  Grand Rapids      US
# 8601    8601  2625 Constitution Dr        Hotels     Livermore      US
#
#         latitude   longitude                                       name  \
# 785    44.570590  -69.640120   Best Western Plus Waterville Grand Hotel
# 649    44.570590  -69.640120   Best Western Plus Waterville Grand Hotel
# 34887  43.680330  -85.483330          Quality Inn and Suites Big Rapids
# 19847  42.912940  -85.532300  Best Western Hospitality Hotel and Suites
# 8601   37.701428 -121.814181                      Comfort Inn Livermore
#
#       postalCode province          reviews.date     reviews.dateAdded  \
# ...

# %%
data_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35912 entries, 0 to 35911
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 35912 non-null  int64
#  1   address               35912 non-null  object
#  2   categories            35912 non-null  object
#  3   city                  35912 non-null  object
#  4   country               35912 non-null  object
#  5   latitude              35826 non-null  float64
#  6   longitude             35826 non-null  float64
#  7   name                  35912 non-null  object
#  8   postalCode            35857 non-null  object
#  9   province              35912 non-null  object
#  10  reviews.date          35653 non-null  object
#  11  reviews.dateAdded     35912 non-null  object
#  12  reviews.doRecommend   0 non-null      float64
#  13  reviews.id            0 non-null      float64
# ...

# %%
for column in data_hotel.columns:
    print(f"====={column}=====")
    display(data_hotel[column].value_counts())
    print()
# Out:
# =====index=====
# 0        1
# 23944    1
# 23938    1
# 23939    1
# 23940    1
#         ..
# 11964    1
# 11963    1
# 11962    1
# 11961    1
# 35911    1
# Name: index, Length: 35912, dtype: int64
# =====address=====
# 480 King St                1185
# 95 Route 17k                714
# 4934 N W Loop 410           546
# 850 Bayview Ave             392
# 375 Main St                 335
#                            ...
# 20 S Toe River Rd             1
# 6481 Post Rd                  1
# 426 E Perry St                1
# 213 Academy St                1
# 8956 Tilghman Island Rd       1
# Name: address, Length: 999, dtype: int64
# =====categories=====
# Hotels                                                           21420
# Hotels,Hotel                                                      2977
# Hotel,Hotels                                                      1524
# Hotels,Hotels & Motels                                             423
# ...

# %%
data_hotel.isnull().sum()
# Out:
# index                       0
# address                     0
# categories                  0
# city                        0
# country                     0
# latitude                   86
# longitude                  86
# name                        0
# postalCode                 55
# province                    0
# reviews.date              259
# reviews.dateAdded           0
# reviews.doRecommend     35912
# reviews.id              35912
# reviews.rating            862
# reviews.text               22
# reviews.title            1622
# reviews.userCity        19649
# reviews.username           43
# reviews.userProvince    18394
# dtype: int64

# %%
data_hotel = data_hotel.drop(columns=['reviews.doRecommend','reviews.id','index','reviews.userCity','reviews.userProvince'])
data_hotel.sample(5)
# Out:
#                    address                                         categories  \
# 34617       560 Peavine Rd  Wedding Sites,Hotels,Hotels & Motels,Meeting F...
# 33474  3243 S Ridge Dr S W                                       Hotels,Hotel
# 28095        7875 E Hwy 69                                             Hotels
# 2851       956 S 25th St W                              Hotels & Motels,Hotel
# 5530           480 King St                                       Hotels,Hotel
#
#                   city country   latitude   longitude  \
# 34617       Crossville      US  35.964270  -84.981420
# 33474     Cedar Rapids      US  41.946156  -91.672390
# 28095  Prescott Valley      US  34.585531 -112.326875
# 2851          Billings      US  45.752200 -108.581040
# 5530        Alexandria      US  38.804740  -77.044550
#
#                                           name  postalCode province  \
# 34617  Holiday Inn Express & Suites Crossville       38571       TN
# ...

# %%
data_hotel.isnull().sum()
# Out:
# address                 0
# categories              0
# city                    0
# country                 0
# latitude               86
# longitude              86
# name                    0
# postalCode             55
# province                0
# reviews.date          259
# reviews.dateAdded       0
# reviews.rating        862
# reviews.text           22
# reviews.title        1622
# reviews.username       43
# dtype: int64

# %%
data_hotel['latitude'] = data_hotel['latitude'].fillna(data_hotel['latitude'].mode()[0])

# %%
data_hotel['longitude'] = data_hotel['longitude'].fillna(data_hotel['longitude'].mode()[0])

# %%
data_hotel['postalCode'] = data_hotel['postalCode'].fillna(data_hotel['postalCode'].mode()[0])

# %%
data_hotel['reviews.rating'] = data_hotel['reviews.rating'].fillna(data_hotel['reviews.rating'].mode()[0])

# %%
data_hotel['reviews.title'] = data_hotel['reviews.title'].fillna(data_hotel['reviews.title'].mode()[0])

# %%
data_hotel['reviews.date'] = data_hotel['reviews.date'].fillna(data_hotel['reviews.date'].mode()[0])

# %%
data_hotel.isnull().sum()
# Out:
# address               0
# categories            0
# city                  0
# country               0
# latitude              0
# longitude             0
# name                  0
# postalCode            0
# province              0
# reviews.date          0
# reviews.dateAdded     0
# reviews.rating        0
# reviews.text         22
# reviews.title         0
# reviews.username     43
# dtype: int64

# %%
data_hotel['reviews.username'] = data_hotel['reviews.username'].replace(np.nan, 'Other')

# %%
data_hotel['reviews.text'] = data_hotel['reviews.text'].replace(np.nan, 'Other')

# %%
data_hotel.isnull().sum()
# Out:
# address              0
# categories           0
# city                 0
# country              0
# latitude             0
# longitude            0
# name                 0
# postalCode           0
# province             0
# reviews.date         0
# reviews.dateAdded    0
# reviews.rating       0
# reviews.text         0
# reviews.title        0
# reviews.username     0
# dtype: int64

# %%
#melihat value other
data_hotel[data_hotel.isin(['Other']).any(axis=1)]
# Out:
#                                address  \
# 925                   Carretera Cancun
# 3214                     505 1st Ave N
# 3594                    133 Holiday Ln
# 3595                    133 Holiday Ln
# 3830   Bia Route 7 Garcia Trading Post
# ...                                ...
# 31318                  35 Via Pico Plz
# 31721                  450 Raynolds St
# 32224                    1805 Birch Rd
# 34200     Blvd Villas De Irapuato 1362
# 34389              2020 N Federal Blvd
#
#                                               categories          city  \
# 925                                               Hotels  Mont Belvieu
# 3214                                        hotel,Hotels       Seattle
# 3594                                     Hotels & Motels       Jellico
# 3595                                     Hotels & Motels       Jellico
# 3830                                              Hotels        Chinle
# ...

# %%
len (data_hotel.drop_duplicates()) /len (data_hotel)
# Out:
# 0.999805079082201

# %%
data_hotel = data_hotel.drop_duplicates()

# %%
data_hotel[data_hotel.isin(['���������������������������']).any(axis=1)]
# Out:
#                             address categories           city country  \
# 7145               Jalan Mh Thamrin     Hotels  Staten Island      US
# 7172               Jalan Mh Thamrin     Hotels  Staten Island      US
# 7179               Jalan Mh Thamrin     Hotels  Staten Island      US
# 7180               Jalan Mh Thamrin     Hotels  Staten Island      US
# 7195               Jalan Mh Thamrin     Hotels  Staten Island      US
# 15435                  95 Route 17k     Hotels       Newburgh      US
# 17994         Grosse Neugasse 36 38     Hotels        Raymond      US
# 25923              6 Avenue Fremiet     Hotels         Irving      US
# 25924              6 Avenue Fremiet     Hotels         Irving      US
# 34200  Blvd Villas De Irapuato 1362     Hotels         Mobile      US
# 34201  Blvd Villas De Irapuato 1362     Hotels         Mobile      US
# 34202  Blvd Villas De Irapuato 1362     Hotels         Mobile      US
#
# ...

# %%
data_hotel
# Out:
#                       address  \
# 0      Riviera San Nicol 11/a
# 1      Riviera San Nicol 11/a
# 2      Riviera San Nicol 11/a
# 3      Riviera San Nicol 11/a
# 4      Riviera San Nicol 11/a
# ...                       ...
# 35907      1088 Powdermill Rd
# 35908      1088 Powdermill Rd
# 35909      1088 Powdermill Rd
# 35910        3747 29th St S E
# 35911        3747 29th St S E
#
#                                               categories          city  \
# 0                                                 Hotels      Mableton
# 1                                                 Hotels      Mableton
# 2                                                 Hotels      Mableton
# 3                                                 Hotels      Mableton
# 4                                                 Hotels      Mableton
# ...                                                  ...           ...
# 35907  Cabins,Resorts & Vacation Cottages,Wedding Cha...    Gatlinburg
# ...

# %%
data_hotel['reviews.title']=data_hotel['reviews.title'].replace(r'^\W*$',np.nan,regex=True)

# %%
data_hotel['reviews.text']=data_hotel['reviews.text'].replace(r'^\W*$',np.nan,regex=True)

# %%
data_hotel.sample(5)
# Out:
#                     address  \
# 32063  222 N Ingram Mill Rd
# 30385    446 Southbridge St
# 11078    1700 Eighth St N W
# 11366      1140 Park Pl N E
# 202                     864
#
#                                               categories          city  \
# 32063                                             Hotels   Springfield
# 30385                                             Hotels        Auburn
# 11078                                       Hotel,Hotels        Austin
# 11366  Hotels,Lodging,Motels,Halls Auditoriums & Ball...  Cedar Rapids
# 202                                               Hotels    Binghamton
#
#       country   latitude  longitude                                  name  \
# 32063      US  37.208500 -93.228160            Greenstay Hotel and Suites
# 30385      US  42.199763 -71.840633        La Quinta Inn Auburn Worcester
# 11078      US  43.681877 -92.983950         Americinn Lodge Suites Austin
# ...

# %%
data_hotel[data_hotel.isin(['���������������������������']).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [address, categories, city, country, latitude, longitude, name, postalCode, province, reviews.date, reviews.dateAdded, reviews.rating, reviews.text, reviews.title, reviews.username]
# Index: []

# %%
data_hotel['reviews.title']
# Out:
# 0        Good location away from the crouds
# 1            Great hotel with Jacuzzi bath!
# 2                               Lugnt l��ge
# 3                Good location on the Lido.
# 4                                       NaN
#                         ...
# 35907           Amazing time (both times!!)
# 35908           Amazing time (both times!!)
# 35909           Amazing time (both times!!)
# 35910                            Great stay
# 35911                            Great stay
# Name: reviews.title, Length: 35905, dtype: object

# %%
data_hotel.isnull().sum()
# Out:
# address                0
# categories             0
# city                   0
# country                0
# latitude               0
# longitude              0
# name                   0
# postalCode             0
# province               0
# reviews.date           0
# reviews.dateAdded      0
# reviews.rating         0
# reviews.text          40
# reviews.title        101
# reviews.username       0
# dtype: int64

# %%
data_hotel['reviews.text'] = data_hotel['reviews.text'].replace(np.nan, 'Other')

# %%
data_hotel['reviews.title'] = data_hotel['reviews.title'].replace(np.nan, 'Other')

# %%
data_hotel['reviews.text']
# Out:
# 0        Pleasant 10 min walk along the sea front to th...
# 1        Really lovely hotel. Stayed on the very top fl...
# 2        Ett mycket bra hotell. Det som drog ner betyge...
# 3        We stayed here for four nights in October. The...
# 4        We stayed here for four nights in October. The...
#                                ...
# 35907    Best of the Best!!!! My family and I stayed in...
# 35908    Amazing Vacation in Beautiful Cabin We stayed ...
# 35909    My husband and I stayed at Tree Tops which is ...
# 35910    to share your opinion of this businesswith YP ...
# 35911           xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Name: reviews.text, Length: 35905, dtype: object

# %%
data_hotel.isnull().sum()
# Out:
# address              0
# categories           0
# city                 0
# country              0
# latitude             0
# longitude            0
# name                 0
# postalCode           0
# province             0
# reviews.date         0
# reviews.dateAdded    0
# reviews.rating       0
# reviews.text         0
# reviews.title        0
# reviews.username     0
# dtype: int64

# %%
data_hotel.sample(50)
# Out:
#                                  address  \
# 5984                      3809 Crain Hwy
# 8906                   2512 W Lincolnway
# 27809                  4934 N W Loop 410
# 5626                         480 King St
# 10924                  905 N Kentucky St
# 20777                    850 Bayview Ave
# 19518                     1880 W 12th St
# 6191           457 Mountain Village Blvd
# 2221                   1 Wenonah Park Pl
# 10502               165 Saint Emanuel St
# 32821               88 E Nationwide Blvd
# 17704                      404 S 44th St
# 21509                       2021 Park Pl
# 12263                     14585 Duval Rd
# 16937                  906 Maple Hill Rd
# 12122                     14585 Duval Rd
# 11850                       135 Route 28
# 15770             Via Villa Rosato 20 22
# 10799                      5 Village Cir
# 15719           5200 Fashion Square Blvd
# 19512                     1880 W 12th St
# 33718                         18 Bath St
# ...

# %%
data_hotel['reviews.text']=data_hotel['reviews.text'].replace(['��'],np.nan,regex=True)
data_hotel['name']=data_hotel['name'].replace(['��'],np.nan,regex=True)
data_hotel['reviews.title']=data_hotel['reviews.title'].replace(['��'],np.nan,regex=True)

# %%
data_hotel.isnull().sum()
# Out:
# address                0
# categories             0
# city                   0
# country                0
# latitude               0
# longitude              0
# name                 275
# postalCode             0
# province               0
# reviews.date           0
# reviews.dateAdded      0
# reviews.rating         0
# reviews.text         186
# reviews.title        487
# reviews.username       0
# dtype: int64

# %%
data_hotel['reviews.text'] = data_hotel['reviews.text'].replace(np.nan, 'Other')
data_hotel['name'] = data_hotel['name'].replace(np.nan, 'Other')
data_hotel['reviews.title'] = data_hotel['reviews.title'].replace(np.nan, 'Other')

# %%
data_hotel.isnull().sum()
# Out:
# address              0
# categories           0
# city                 0
# country              0
# latitude             0
# longitude            0
# name                 0
# postalCode           0
# province             0
# reviews.date         0
# reviews.dateAdded    0
# reviews.rating       0
# reviews.text         0
# reviews.title        0
# reviews.username     0
# dtype: int64

# %%
data_hotel['reviews.title']
# Out:
# 0        Good location away from the crouds
# 1            Great hotel with Jacuzzi bath!
# 2                                     Other
# 3                Good location on the Lido.
# 4                                     Other
#                         ...
# 35907           Amazing time (both times!!)
# 35908           Amazing time (both times!!)
# 35909           Amazing time (both times!!)
# 35910                            Great stay
# 35911                            Great stay
# Name: reviews.title, Length: 35905, dtype: object

# %%
data_hotel.sample(50)
# Out:
#                                  address  \
# 26779                  3107 Atlantic Ave
# 32428                     603 Adcolor Dr
# 14199                    40 Apollonos St
# 28442                      121 Raydo Cir
# 21510                       2021 Park Pl
# 30299          9023 Annapolis Road/i 495
# 9800                  2645 N W Inlet Ave
# 29055                    355 Santana Row
# 17630               1725 Long Beach Blvd
# 8605                2625 Constitution Dr
# 17922                       Via Regina 1
# 6853                  4691 Castleton Way
# 7032         Av Juarez 76 Colonel Centro
# 1880                6390 Us Highway 93 S
# 22129                 22617 Ventura Blvd
# 11664                  3250 Northview Dr
# 1281                     720 E Harbor St
# 25131                     7865 Perry Hwy
# 30769                 3005 Franklin Blvd
# 24733                       3320 Mesa Rd
# 32996                    5040 Redwood Dr
# 13898                  3100 Regency Pkwy
# ...

# %%
data_hotel
# Out:
#                       address  \
# 0      Riviera San Nicol 11/a
# 1      Riviera San Nicol 11/a
# 2      Riviera San Nicol 11/a
# 3      Riviera San Nicol 11/a
# 4      Riviera San Nicol 11/a
# ...                       ...
# 35907      1088 Powdermill Rd
# 35908      1088 Powdermill Rd
# 35909      1088 Powdermill Rd
# 35910        3747 29th St S E
# 35911        3747 29th St S E
#
#                                               categories          city  \
# 0                                                 Hotels      Mableton
# 1                                                 Hotels      Mableton
# 2                                                 Hotels      Mableton
# 3                                                 Hotels      Mableton
# 4                                                 Hotels      Mableton
# ...                                                  ...           ...
# 35907  Cabins,Resorts & Vacation Cottages,Wedding Cha...    Gatlinburg
# ...

# %%
data_hotel['reviews.title']=data_hotel['reviews.title'].replace('Amazing time (both times!!)', 'Other')

# %%
data_hotel
# Out:
#                       address  \
# 0      Riviera San Nicol 11/a
# 1      Riviera San Nicol 11/a
# 2      Riviera San Nicol 11/a
# 3      Riviera San Nicol 11/a
# 4      Riviera San Nicol 11/a
# ...                       ...
# 35907      1088 Powdermill Rd
# 35908      1088 Powdermill Rd
# 35909      1088 Powdermill Rd
# 35910        3747 29th St S E
# 35911        3747 29th St S E
#
#                                               categories          city  \
# 0                                                 Hotels      Mableton
# 1                                                 Hotels      Mableton
# 2                                                 Hotels      Mableton
# 3                                                 Hotels      Mableton
# 4                                                 Hotels      Mableton
# ...                                                  ...           ...
# 35907  Cabins,Resorts & Vacation Cottages,Wedding Cha...    Gatlinburg
# ...

# %%
data_hotel.sample(50)
# Out:
#                                                 address  \
# 18494                                    3083 Carman Rd
# 14578                                     600 Tracy Trl
# 4838                                        480 King St
# 28864                                 2607 Atlantic Ave
# 34158                                  214 N Hunter Hwy
# 8266                                454 Jenness Pond Rd
# 7139                                   Jalan Mh Thamrin
# 18786                                  8710 S Hosmer St
# 2743                                  507 Minnesota Ave
# 27791                                 4934 N W Loop 410
# 32446                           Paseo De La Quinta No 6
# 33943                                 1209 S Haynes Ave
# 5271                                        480 King St
# 11189                           24320 Rogers Clark Blvd
# 15661                          5200 Fashion Square Blvd
# 16266                            102 Avenue Victor Hugo
# ...

# %%
data_hotel[data_hotel.isin(['Other']).any(axis=1)]
# Out:
#                       address  \
# 2      Riviera San Nicol 11/a
# 4      Riviera San Nicol 11/a
# 8      Riviera San Nicol 11/a
# 10     Riviera San Nicol 11/a
# 14     Riviera San Nicol 11/a
# ...                       ...
# 35686   100 Paterson Plank Rd
# 35906      1088 Powdermill Rd
# 35907      1088 Powdermill Rd
# 35908      1088 Powdermill Rd
# 35909      1088 Powdermill Rd
#
#                                               categories        city country  \
# 2                                                 Hotels    Mableton      US
# 4                                                 Hotels    Mableton      US
# 8                                                 Hotels    Mableton      US
# 10                                                Hotels    Mableton      US
# 14                                                Hotels    Mableton      US
# ...                                                  ...         ...     ...
# ...

# %%
#save data clean
data_hotel.to_excel('Data_Hotel_Clean.xlsx')
